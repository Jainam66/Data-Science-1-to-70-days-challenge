# %% [markdown]
# <a href="https://colab.research.google.com/github/Jainam66/Data-Science-1-to-70-days-challenge/blob/main/Day-3%20Pandas2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Salaries.csv")

# %% [markdown]
# AND operator

# %%
newdf=df[(df['sex']=='Male')&(df["salary"]>150000)]

# %%
newdf
# Out:
#     rank discipline  phd  service   sex  salary
# 0   Prof          B   56       49  Male  186960
# 13  Prof          B   35       33  Male  162200
# 14  Prof          B   25       19  Male  153750
# 15  Prof          B   17        3  Male  150480
# 19  Prof          A   29       27  Male  150500
# 27  Prof          A   45       43  Male  155865
# 31  Prof          B   22       21  Male  155750

# %%
#shape for total count
newdf.shape[0]
# Out:
# 7

# %% [markdown]
# OR operator

# %%
df[(df["service"]>15)|(df["salary"]>1000000)]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# ...

# %%
df[(df["service"]>15)|(df["salary"]>1000000)].shape[0]
# Out:
# 37

# %% [markdown]
# Index Location

# %%
df.iloc[5]
# Out:
# rank            Prof
# discipline         A
# phd               20
# service           20
# sex             Male
# salary        122400
# Name: 5, dtype: object

# %%
df.head(5)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.iloc[1:10,2:4]
# Out:
#    phd  service
# 1   12        6
# 2   23       20
# 3   40       31
# 4   20       18
# 5   20       20
# 6   20       17
# 7   18       18
# 8   29       19
# 9   51       51

# %%
df.iloc[:,4]
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.loc[:,["rank","sex"]]
# Out:
#          rank     sex
# 0        Prof    Male
# 1        Prof    Male
# 2        Prof    Male
# 3        Prof    Male
# 4        Prof    Male
# ..        ...     ...
# 73       Prof  Female
# 74  AssocProf  Female
# 75       Prof  Female
# 76       Prof  Female
# 77       Prof  Female
#
# [78 rows x 2 columns]

# %%
df.loc[[10,20,30,40],["rank","sex"]]
# Out:
#          rank     sex
# 10       Prof    Male
# 20   AsstProf    Male
# 30  AssocProf    Male
# 40       Prof  Female

# %% [markdown]
# Common Aggregation Function

# %%
df[["phd","salary"]].agg(["min","max","mean","std"])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# max   56.000000  186960.000000
# mean  19.705128  108023.782051
# std   12.498425   28293.661022

# %%
df["salary"].agg("kurt")
# Out:
# -0.4017126758820546

# %%
df["salary"].agg("var")
# Out:
# 800531254.0427907

# %%
df.sem() #std error of mean - standard error i.e sigma/square root of n
